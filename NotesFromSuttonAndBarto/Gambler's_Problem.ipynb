# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# number of states
n=101

# %%
# Analysis with discount factor 1

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.4
pt=(1-ph)

# discount factor
gamma=1


_,ax=plt.subplots(1,1,figsize=(10,5))


for k in range(32):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))

    if k in (0,1,2):
        ax.plot(range(1,n-1),v[1:-1],label='Sweep {}'.format(k))

ax.plot(range(1,n-1),v[1:-1],label='Sweep {}'.format(k))
plt.legend()

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.55
pt=(1-ph)

# discount factor
gamma=1


_,ax=plt.subplots(1,1,figsize=(10,5))


for k in range(32):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))

    if k in (0,1,2):
        ax.plot(range(1,n-1),v[1:-1],label='Sweep {}'.format(k))

ax.plot(range(1,n-1),v[1:-1],label='Sweep {}'.format(k))
plt.legend()

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.75
pt=(1-ph)

# discount factor
gamma=1


_,ax=plt.subplots(1,1,figsize=(10,5))


for k in range(32):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))

    if k in (0,1,2):
        ax.plot(range(1,n-1),v[1:-1],label='Sweep {}'.format(k))

ax.plot(range(1,n-1),v[1:-1],label='Sweep {}'.format(k))
plt.legend()

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.4
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.49
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(1,min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
delta,k
# Out:
# (2.96637714392034e-16, 26)

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.5
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
delta,k
# Out:
# (1.249000902703301e-16, 16)

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.51
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
delta,k
# Out:
# (9.992007221626409e-16, 19453)

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.55
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
delta,k
# Out:
# (9.992007221626409e-16, 2874)

# %%
_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions[allowed_actions<=1])),allowed_actions[allowed_actions<=1],"o",c=cp[s])
    axs[1].plot(s*np.ones(len(allowed_actions[allowed_actions>1])),allowed_actions[allowed_actions>1],"o",c='r')

axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
allowed_actions
# Out:
# array([0, 1])

# %%
# Analysis with discount factor 1-1e-5

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.49
pt=(1-ph)

# discount factor
gamma=1-1e-5

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.55
pt=(1-ph)

# discount factor
gamma=1-1e-5

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capitala')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
# Miscellaneous

# %%
k=9
n=2**k-2**(k-1)+1
n

# %%
k=11
n=2**k-2**(k-1)+1

# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.4
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}, k={}, n={}'.format(ph,k,n))
plt.show()

# %%
_,ax=plt.subplots(1,1,figsize=(10,10))
for k in range(1,11):
    n=2**k-2**(k-1)+1
    x=np.linspace(0,1,n)
    ax.plot(x,v[:n]/v[n-1])

# %%
k=11
n=2**k-2**(k-1)+1

# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[n-1]=1.0

# probability of heads and tails
ph=.55
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}, k={}, n={}'.format(ph,k,n))
plt.show()

# %%
_,ax=plt.subplots(1,1,figsize=(10,10))
for k in range(1,11):
    n=2**k-2**(k-1)+1
    x=np.linspace(0,1,n)
    ax.plot(x,v[:n]/v[n-1])

# %%
n=101
# state values
v=np.zeros(n)

# rewards
r=np.zeros(n)
r[:-1]=-1.0

# probability of heads and tails
ph=.45
pt=(1-ph)

# discount factor
gamma=1

# threshold
theta=1e-15

for k in range(30000):
    delta=0.0
    for s in range(1,n-1):
        w=v[s]
        actions=np.array(range(min(s,n-1-s)+1))
        x=[ ph*r[s+a]+pt*r[s-a] + gamma*(ph*v[s+a]+pt*v[s-a]) for a in actions]
        v[s]=max(x)
        delta=max(delta,abs(w-v[s]))
    
    if delta < theta:
        break

_,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(range(1,n-1),v[1:-1])

cp=sns.dark_palette("#69d", n,reverse=True)
for s in range(1,n-1):
    actions=np.array(range(min(s,n-1-s)+1))
    x=[ ph*(r[s+a]+v[s+a])+pt*(r[s-a]+v[s-a]) for a in actions]
    allowed_actions=actions[np.isclose(x,np.max(x),rtol=1e-8)]
    axs[1].plot(s*np.ones(len(allowed_actions)),allowed_actions,"o",c=cp[s])
axs[0].set_xlabel('Capital')
axs[1].set_xlabel('Capital')
axs[0].set_ylabel('Final Value')
axs[1].set_ylabel('Final Policy (stake)')
plt.suptitle('$p_h$={}'.format(ph))
plt.show()

# %%
r
